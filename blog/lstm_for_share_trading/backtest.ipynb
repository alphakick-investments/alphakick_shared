# %% [markdown]
# # Backtest

# %%
# %load_ext autoreload
# %autoreload 2
    
import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])
from backtrader.feeds import PandasData

# Import the backtrader platform
import backtrader as bt

import pandas as pd
from util import *

# %%
TICKER = 'amzn' # Change to aapl or googl to see the results for these companies
PATH = 'output/'
CASH = 10000
COMMISSION = 0.001
STAKE = 1

# %%
df = pd.read_csv('{}{}_preds_stacked_lstm.csv'.format(PATH, TICKER), index_col='date')
#df = pd.read_csv('{}{}_preds_encoder_decoder_lstm.csv'.format(PATH, TICKER), index_col='date')
#df = pd.read_csv('{}{}_preds_encoder_decoder_attention_lstm.csv'.format(PATH, TICKER), index_col='date')
df.index = pd.to_datetime(df.index)
df.index.name = 'datetime'
data = SignalData(dataname=df)

# %%
df.dropna(inplace=True)
df.tail()
# Out:
#                open     high    close     volume      preds
# datetime
# 2020-11-11  3061.78  3139.14  3137.39  4366923.0  3063.1570
# 2020-11-12  3159.95  3175.88  3110.28  4371208.0  3039.0684
# 2020-11-13  3122.00  3141.72  3128.81  3762587.0  3027.6182
# 2020-11-16  3093.20  3142.70  3131.06  3808676.0  3024.3325
# 2020-11-17  3183.54  3189.25  3135.66  3444735.0  3026.7595

# %% [markdown]
# # Benchmark

# %%
# Create a cerebro entity
cerebro = bt.Cerebro()

# Add a strategy
cerebro.addstrategy(BenchmarkStrategy)

# Add the Data Feed to Cerebro
cerebro.adddata(data)

# Set our desired cash start
cerebro.broker.setcash(CASH)

# Add a FixedSize sizer according to the stake
cerebro.addsizer(bt.sizers.FixedSize, stake=STAKE)

# Set the commission
cerebro.broker.setcommission(commission=COMMISSION)

# Print out the starting conditions
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

# Run over everything
cerebro.run()

# Print out the final result
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 10000.00
# 2020-03-30, Close, 1963.95
# 2020-03-30, BUY CREATE, 1963.95
# 2020-03-31, BUY EXECUTED, Price: 1964.35, Cost: 1964.35, Comm 1.96
# 2020-03-31, Close, 1949.72
# 2020-04-01, Close, 1907.70
# 2020-04-02, Close, 1918.83
# 2020-04-03, Close, 1906.59
# 2020-04-06, Close, 1997.59
# 2020-04-07, Close, 2011.60
# 2020-04-08, Close, 2043.00
# 2020-04-09, Close, 2042.76
# 2020-04-13, Close, 2168.87
# 2020-04-14, Close, 2283.32
# 2020-04-15, Close, 2307.68
# 2020-04-16, Close, 2408.19
# 2020-04-17, Close, 2375.00
# 2020-04-20, Close, 2393.61
# 2020-04-21, Close, 2328.12
# 2020-04-22, Close, 2363.49
# 2020-04-23, Close, 2399.45
# 2020-04-24, Close, 2410.22
# 2020-04-27, Close, 2376.00
# 2020-04-28, Close, 2314.08
# 2020-04-29, Close, 2372.71
# 2020-04-30, Close, 2474.00
# 2020-05-01, Close, 2286.04
# 2020-05-04, Close, 2315.99
# 2020-05-05, Close, 2317.80
# 2020-05-06, Close, 2351.26
# 2020-05-07, Close, 2367.61
# 2020-05-08, Close, 2379.61
# 2020-05-11, Close, 2409.00
# 2020-05-12, Close, 2356.95
# 2020-05-13, Close, 2367.92
# 2020-05-14, Close, 2388.85
# 2020-05-15, Close, 2409.78
# 2020-05-18, Close, 2426.26
# 2020-05-19, Close, 2449.33
# 2020-09-24, Close, 3019.79
# 2020-09-25, Close, 3095.13
# 2020-09-28, Close, 3174.05
# 2020-09-29, Close, 3144.88
# 2020-09-30, Close, 3148.73
# 2020-10-01, Close, 3221.26
# 2020-10-02, Close, 3125.00
# 2020-10-05, Close, 3199.20
# 2020-10-06, Close, 3099.96
# 2020-10-07, Close, 3195.69
# 2020-10-08, Close, 3190.55
# 2020-10-09, Close, 3286.65
# 2020-10-12, Close, 3442.93
# 2020-10-13, Close, 3443.63
# 2020-10-14, Close, 3363.71
# 2020-10-15, Close, 3338.65
# 2020-10-16, Close, 3272.71
# 2020-10-19, Close, 3207.21
# 2020-10-20, Close, 3217.01
# 2020-10-21, Close, 3184.94
# 2020-10-22, Close, 3176.40
# 2020-10-23, Close, 3204.40
# 2020-10-26, Close, 3207.04
# 2020-10-27, Close, 3286.33
# 2020-10-28, Close, 3162.78
# 2020-10-29, Close, 3211.01
# 2020-10-30, Close, 3036.15
# 2020-11-02, Close, 3004.48
# 2020-11-03, Close, 3048.41
# 2020-11-04, Close, 3241.16
# 2020-11-05, Close, 3322.00
# 2020-11-06, Close, 3311.37
# 2020-11-09, Close, 3143.74
# 2020-11-10, Close, 3035.02
# 2020-11-11, Close, 3137.39
# 2020-11-12, Close, 3110.28
# 2020-11-13, Close, 3128.81
# 2020-11-16, Close, 3131.06
# 2020-11-17, Close, 3135.66
# 2020-11-17, SELL CREATE, 3135.66
# Final Portfolio Value: 11169.35

# %% [markdown]
# # Apply TestStrategy On Predictions

# %%
# Create a cerebro entity
cerebro = bt.Cerebro()

# Add a strategy
cerebro.addstrategy(TestStrategy)

# Add the Data Feed to Cerebro
cerebro.adddata(data)

# Set our desired cash start
cerebro.broker.setcash(CASH)

# Add a FixedSize sizer according to the stake
cerebro.addsizer(bt.sizers.FixedSize, stake=STAKE)

# Set the commission
cerebro.broker.setcommission(commission=COMMISSION)

# Print out the starting conditions
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

# Run over everything
cerebro.run()

# Print out the final result
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 10000.00
# 2020-03-30, Close, 1963.95
# 2020-03-31, Close, 1949.72
# 2020-04-01, Close, 1907.70
# 2020-04-01, BUY CREATE, 1907.70
# 2020-04-02, BUY EXECUTED, Price: 1901.64, Cost: 1901.64, Comm 1.90
# 2020-04-02, Close, 1918.83
# 2020-04-03, Close, 1906.59
# 2020-04-06, Close, 1997.59
# 2020-04-07, Close, 2011.60
# 2020-04-08, Close, 2043.00
# 2020-04-09, Close, 2042.76
# 2020-04-13, Close, 2168.87
# 2020-04-14, Close, 2283.32
# 2020-04-15, Close, 2307.68
# 2020-04-16, Close, 2408.19
# 2020-04-17, Close, 2375.00
# 2020-04-20, Close, 2393.61
# 2020-04-21, Close, 2328.12
# 2020-04-22, Close, 2363.49
# 2020-04-23, Close, 2399.45
# 2020-04-24, Close, 2410.22
# 2020-04-27, Close, 2376.00
# 2020-04-28, Close, 2314.08
# 2020-04-29, Close, 2372.71
# 2020-04-30, Close, 2474.00
# 2020-05-01, Close, 2286.04
# 2020-05-04, Close, 2315.99
# 2020-05-05, Close, 2317.80
# 2020-05-06, Close, 2351.26
# 2020-05-07, Close, 2367.61
# 2020-05-08, Close, 2379.61
# 2020-05-11, Close, 2409.00
# 2020-05-12, Close, 2356.95
# 2020-05-13, Close, 2367.92
# 2020-05-14, Close, 2388.85
# 2020-05-15, Close, 2409.78
# 2020-05-18, Close, 2426.26
# 2020-05-19, Close, 2449.33
# 2020-05-20, Close, 2497.94
# 2020-05-21, Close, 2446.74
# 2020-05-22, Close, 2436.88
# 2020-05-22, SELL CREATE, 2436.88
# 2020-05-26, SELL EXECUTED, Price: 2458.00, Cost: 1901.64, Comm 2.46
# 2020-05-26, OPERATION PROFIT, GROSS 556.36, NET 552.00
# 2020-05-26, Close, 2421.86
# 2020-05-27, Close, 2410.39
# 2020-05-28, Close, 2401.10
# 2020-05-29, Close, 2442.37
# 2020-06-01, Close, 2471.04
# 2020-06-02, Close, 2472.41
# 2020-06-03, Close, 2478.40
# 2020-06-04, Close, 2460.60
# 2020-06-05, Close, 2483.00
# 2020-06-08, Close, 2524.06
# 2020-06-09, Close, 2600.86
# 2020-06-10, Close, 2647.45
# 2020-06-11, Close, 2557.96
# 2020-06-12, Close, 2545.02
# 2020-06-15, Close, 2572.68
# 2020-06-16, Close, 2615.27
# 2020-06-17, Close, 2640.98
# 2020-06-18, Close, 2653.98
# 2020-06-19, Close, 2675.01
# 2020-06-22, Close, 2713.82
# 2020-06-23, Close, 2764.41
# 2020-06-24, Close, 2734.40
# 2020-06-25, Close, 2754.58
# 2020-06-26, Close, 2692.87
# 2020-06-29, Close, 2680.38
# 2020-06-30, Close, 2758.82
# 2020-07-01, Close, 2878.70
# 2020-07-02, Close, 2890.30
# 2020-07-06, Close, 3057.04
# 2020-07-07, Close, 3000.12
# 2020-07-08, Close, 3081.11
# 2020-07-09, Close, 3182.63
# 2020-07-10, Close, 3200.00
# 2020-07-13, Close, 3104.00
# 2020-07-14, Close, 3084.00
# 2020-07-15, Close, 3008.87
# 2020-07-15, BUY CREATE, 3008.87
# 2020-07-16, BUY EXECUTED, Price: 2971.06, Cost: 2971.06, Comm 2.97
# 2020-07-16, Close, 2999.90
# 2020-07-16, SELL CREATE, 2999.90
# 2020-07-17, SELL EXECUTED, Price: 3009.00, Cost: 2971.06, Comm 3.01
# 2020-07-17, OPERATION PROFIT, GROSS 37.94, NET 31.96
# 2020-07-17, Close, 2961.97
# 2020-07-20, Close, 3196.84
# 2020-07-21, Close, 3138.29
# 2020-07-22, Close, 3099.91
# 2020-07-23, Close, 2986.55
# 2020-07-24, Close, 3008.91
# 2020-07-27, Close, 3055.21
# 2020-07-28, Close, 3000.33
# 2020-07-29, Close, 3033.53
# 2020-07-30, Close, 3051.88
# 2020-07-31, Close, 3164.68
# 2020-08-03, Close, 3111.89
# 2020-08-04, Close, 3138.83
# 2020-08-05, Close, 3205.03
# 2020-08-06, Close, 3225.00
# 2020-08-07, Close, 3167.46
# 2020-08-10, Close, 3148.16
# 2020-08-11, Close, 3080.67
# 2020-08-12, Close, 3162.24
# 2020-08-13, Close, 3161.02
# 2020-08-14, Close, 3148.02
# 2020-08-17, Close, 3182.41
# 2020-08-18, Close, 3312.49
# 2020-08-19, Close, 3260.48
# 2020-08-20, Close, 3297.37
# 2020-08-21, Close, 3284.72
# 2020-08-24, Close, 3307.46
# 2020-08-25, Close, 3346.49
# 2020-08-26, Close, 3441.85
# 2020-08-27, Close, 3400.00
# 2020-08-28, Close, 3401.80
# 2020-08-31, Close, 3450.96
# 2020-09-01, Close, 3499.12
# 2020-09-02, Close, 3531.45
# 2020-09-03, Close, 3368.00
# 2020-09-04, Close, 3294.62
# 2020-09-08, Close, 3149.84
# 2020-09-08, BUY CREATE, 3149.84
# 2020-09-09, BUY EXECUTED, Price: 3202.99, Cost: 3202.99, Comm 3.20
# 2020-09-09, Close, 3268.61
# 2020-09-10, Close, 3175.11
# 2020-09-11, Close, 3116.22
# 2020-09-11, SELL CREATE, 3116.22
# 2020-09-14, SELL EXECUTED, Price: 3172.94, Cost: 3202.99, Comm 3.17
# 2020-09-14, OPERATION PROFIT, GROSS -30.05, NET -36.43
# 2020-09-14, Close, 3102.97
# 2020-09-15, Close, 3156.13
# 2020-09-16, Close, 3078.10
# 2020-09-17, Close, 3008.73
# 2020-09-18, Close, 2954.91
# 2020-09-21, Close, 2960.47
# 2020-09-22, Close, 3128.99
# 2020-09-23, Close, 2999.86
# 2020-09-24, Close, 3019.79
# 2020-09-25, Close, 3095.13
# 2020-09-28, Close, 3174.05
# 2020-09-29, Close, 3144.88
# 2020-09-30, Close, 3148.73
# 2020-10-01, Close, 3221.26
# 2020-10-02, Close, 3125.00
# 2020-10-05, Close, 3199.20
# 2020-10-06, Close, 3099.96
# 2020-10-07, Close, 3195.69
# 2020-10-08, Close, 3190.55
# 2020-10-09, Close, 3286.65
# 2020-10-12, Close, 3442.93
# 2020-10-13, Close, 3443.63
# 2020-10-14, Close, 3363.71
# 2020-10-15, Close, 3338.65
# 2020-10-16, Close, 3272.71
# 2020-10-19, Close, 3207.21
# 2020-10-20, Close, 3217.01
# 2020-10-21, Close, 3184.94
# 2020-10-22, Close, 3176.40
# 2020-10-23, Close, 3204.40
# 2020-10-26, Close, 3207.04
# 2020-10-27, Close, 3286.33
# 2020-10-28, Close, 3162.78
# 2020-10-29, Close, 3211.01
# 2020-10-30, Close, 3036.15
# 2020-10-30, BUY CREATE, 3036.15
# 2020-11-02, BUY EXECUTED, Price: 3061.74, Cost: 3061.74, Comm 3.06
# 2020-11-02, Close, 3004.48
# 2020-11-03, Close, 3048.41
# 2020-11-04, Close, 3241.16
# 2020-11-05, Close, 3322.00
# 2020-11-06, Close, 3311.37
# 2020-11-09, Close, 3143.74
# 2020-11-09, SELL CREATE, 3143.74
# 2020-11-10, SELL EXECUTED, Price: 3095.02, Cost: 3061.74, Comm 3.10
# 2020-11-10, OPERATION PROFIT, GROSS 33.28, NET 27.12
# 2020-11-10, Close, 3035.02
# 2020-11-10, BUY CREATE, 3035.02
# 2020-11-11, BUY EXECUTED, Price: 3061.78, Cost: 3061.78, Comm 3.06
# 2020-11-11, Close, 3137.39
# 2020-11-12, Close, 3110.28
# 2020-11-13, Close, 3128.81
# 2020-11-16, Close, 3131.06
# 2020-11-17, Close, 3135.66
# 2020-11-17, SELL CREATE, 3135.66
# Final Portfolio Value: 10645.48
